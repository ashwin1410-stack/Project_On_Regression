# %% [markdown]
# # Heart Dieases Prediction (Logistic Regression)

# %% [markdown]
# *Importing Libraries*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# *Reading CSV*

# %%
data=pd.read_csv("/content/framingham.csv")
data
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %% [markdown]
# *Data Insights*

# %%
data.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %% [markdown]
# *Provides some information regarding the columns in the data*

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4209 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %% [markdown]
# *Statistical Details*

# %%
data.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4238.000000  4238.000000  4133.000000    4238.000000  4209.000000
# mean      0.429212    49.584946     1.978950       0.494101     9.003089
# std       0.495022     8.572160     1.019791       0.500024    11.920094
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4185.000000      4238.000000   4238.000000  4238.000000  4188.000000
# mean      0.029630         0.005899      0.310524     0.025720   236.721585
# std       0.169584         0.076587      0.462763     0.158316    44.590334
# ...

# %% [markdown]
# *Handling Missing Value*

# %%
data.isna().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %% [markdown]
# *Filling Missing Value*

# %%
data["education"].fillna(data["education"].mean(),inplace=True)
data["cigsPerDay"].fillna(data["cigsPerDay"].mean(),inplace=True)
data["BPMeds"].fillna(data["BPMeds"].mean(),inplace=True)
data["totChol"].fillna(data["totChol"].mean(),inplace=True)
data["BMI"].fillna(data["BMI"].mean(),inplace=True)
data["heartRate"].fillna(data["heartRate"].mean(),inplace=True)
data["glucose"].fillna(data["glucose"].mean(),inplace=True)

# %%
data.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# *Data Visualization*

# %%
plt.figure(figsize=(6,6),edgecolor="black",clear=True)
sns.countplot(x=data["TenYearCHD"])
plt.xlabel("TenYearCHD")
plt.ylabel("Count")
plt.title("Distribution Of Ten Year CHD")
plt.show()

# %% [markdown]
# *Corr-relation among columns*

# %%
plt.figure(figsize=(20,20))
corr=data.corr()
sns.heatmap(corr,annot=True,linecolor="white",cbar=Trues,quare=True)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.barplot(x=data["diabetes"],y=data["cigsPerDay"],data=data)
plt.xlabel("Diabetes")
plt.ylabel("Cigratte/Day")
plt.title("Cigratte/Day VS Daibetes")
plt.show()

# %% [markdown]
# From this plot we can tell that there is no relationship between people
# who are consuming cigarettes and people who are getting diabetes

# %% [markdown]
# *Cooking the data*

# %%
x=data.drop("TenYearCHD", axis='columns')
y=data["TenYearCHD"]

# %% [markdown]
# *Splitiing into training and testing datasets*

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,train_size=0.2)

# %% [markdown]
# *Importing Logistic Regression model from scikit learn*

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR=LogisticRegression()
LR.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=LR.predict(X_test)

# %%
print("Testing score :",LR.score(X_test,y_test))
print("Training score :",LR.score(X_train,y_train))
# Out:
# Testing score : 0.8528457682099676
# Training score : 0.8394332939787486

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# We can tell that we are 85% Accurate
